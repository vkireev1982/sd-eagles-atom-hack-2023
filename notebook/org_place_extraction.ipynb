# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#   inflating: all_applic.dat
#   inflating: all_meta.dat
#   inflating: readme.md

# %%
# !cat all_meta.dat | head -5
# Out:
# *$*
# Дата выхода: 2023-04-11
# Установлены результаты первого из трех башен в морской ветряной трубе на острове Янцзы
# (Контингент: CGN-20180529004)
# Первый три башни проекта морской ветровой энергетики на Кананге, Китай, и Яньцзян (заявление No CGN-20180529004)

# %%
import re
import torch
import numpy as np
import pandas as pd

from typing import List, Tuple, Dict, Any
from tqdm.notebook import tqdm
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification, TokenClassificationPipeline
from transformers import XLMRobertaTokenizerFast, XLMRobertaForTokenClassification

pd.set_option('display.max_colwidth', 200)


def extract_CGN(string: str) -> str:
    # codes: List[str] = re.findall("CGN-.*\s*[0-9]+[A-Z]*[0-9]*", string)
    codes: List[str] = re.findall("[0-9]{9,}[A-Z]*[0-9]*", string)
    if len(codes) == 0:
        return ""
    code: str = re.findall("[0-9]+\S+", codes[0])[0]
    return code


with open("/content/all_applic.dat") as f:
    all_applic = f.read()
all_applic = all_applic.split("*$*")[3:]

docs = list(map(lambda x: x.split("\n")[2], all_applic))
texts = list(map(lambda x: "\n".join(x.split("\n")[3:]), all_applic))

df = pd.DataFrame(data=list(zip(docs, texts)), columns=["docs",  "text"])
df["text"] = df["text"].str.replace("&gt;", "")
df["text"] = df["text"].str.replace("&lt;", "")
df["text"] = df["text"].str.replace("&quot;", "")
mask = df["text"].str.len() > 10
df = df.loc[mask].reset_index(drop=True)


df["docs"] = df["docs"].apply(lambda x: re.findall("[0-9]+-[0-9]+", x)[0])
df["CGN"] = df["text"].apply(extract_CGN)


# df_meta = pd.read_excel("/content/result.xlsx")
# mask = df_meta["Контингент:"].isna()
# df_meta.loc[mask] = "nan"
# df_meta["CGN"] = df_meta["Контингент:"].apply(extract_CGN)
# res = pd.merge(df, df_meta, left_on="CGN", right_on="CGN", how="inner")

# %%
all_applic[:2]
# Out:
# ['\n20230731_12345\nКитайский документ 8-8trans.txt\nСиньцзян-Китайская база экологически чистой энергии в Синьцзяне, Лоуп, 1 млн. кВт оптико-волнового поля PC\n(Контингент: CGN-202307050014)\nТерритория, в которой находятся тендерные проекты: Синьцзян-Уйгурский автономный район и Тэгу, округ Лоуп\nУсловия торгов\nВ рамках этого проекта на базе экологически чистой энергетики в Синьцзяне в Лоупе 1 млн. кВт (проект тендера)\nНомер: CGN-202307050014, одобренный подразделением по утверждению проектов, финансируется за счет средств, полученных от предприятия, и реализовано, торгующее\nChina Solar Energy Successing Ltd. В рамках этого проекта уже имеются условия для проведения торгов и в настоящее время проводятся открытые торги.\nII. ОБЩИЙ ОБЗОР ПРОЕКТОВ, ОГРАНИЧЕННОСТИ И ПЛАНИРОВАНИЯ ПРОЕКТОВ\nРазмер проекта:\nСиньцзян-цзян, Китай, Новая энергетическая база мощностью 1 000 000 000 000 000 000 000 кигаваттских люминесцентных оптических дисков в районе Лоуп\nМесто планирования расположено в юго-западном пригороде округа Лоуп, который расположен примерно в 22 км к юго-востоку от города Теда, в районе площадью Гоби-Бич, в пределах участка.\nПлощадка более плоская, открытая площадка, близость к G3012 и автомагистралей, удобство движения.\nПринципы разграничения и выдачи подрядов:\nОбщий контрактный проект PC в 1 млн кВт-диапазоне на базе экологически чистой энергии в Синьцзяне разделен на два пакета из четырех.\nПункт гласит:\nУпаковка 1:\n1-й этап проекта генерального подряда на PC в 1 млн. кВт-диапазоне Лоуп на базе экологически чистой энергии в Синьцзяне;\n2-й пункт генерального подряда на проект PC в 1 млн. кВт-диапазоне на базе экологически чистой энергии в Синьцзяне;\nУпаковка 2:\n3 пункта генерального контракта на реализацию проекта PC в 1 млн. кВт-диапазоне Лоупа на базе экологически чистой энергии в Синьцзяне;\n4 пункта генерального подряда на проект PC в 1 млн кВт-диапазоне на базе экологически чистой энергии в Синьцзяне;\nПринцип оферты: участник процедур может выбрать одну или две упаковки одновременно, но два пункта в одной и той же упаковке должны быть одновременно\nДля каждого сегмента тендерной заявки в упаковке проводится отдельная оценка, а для одного из участников конкурса - только один пункт, который не может быть включен.\nЕсли в пакете 1 (или упаковке 2) первые два тендерных пункта относятся к одному и тому же участнику торгов, то Комиссия по маркетингу основывается на пакете 1 (или пакете)\nii) упорядочение последовательности кандидатов, указанных в пунктах назначения в пакете с минимальными суммами, и в том же пункте, в котором объединенная позиция основывается на предыдущем месте\nУчастники торгов, которые не были рекомендованы в качестве первого кандидата в соответствии с настоящим пунктом или другим пунктом в той же упаковке, не должны иметь права на участие в торгах после того, как они были отобраны.\nВ этом пункте рекомендуется быть первым кандидатом. За исключением тех случаев, когда в соответствии с вышеупомянутыми принципами корректируется первоначальная кандидатская баллотировка, остальные кандидаты, выигравшие конкурс, по-прежнему представлены в сводном порядке\nРекомендуется последовательность.\nСодержание и объем торгов:\nУпаковка 1: первый этап проекта генерального подряда на PC в 1 млн. кВт-диапазоне Лоупо на базе экологически чистой энергетики в Синьцзяне\nПроект охватывает 250 000 кВт (с точки обмена) в радиусе 1 млн. кВт для проекта фотоэлектрического хранения в округе Лоуп.\nСтроительные работы в полном объеме, включая, но не ограничиваясь ими, следующие элементы: закупка оборудования и материалов (за исключением А), установка\nПогрузочно-разгрузочные машины и склады материалов (включая палубу), оборудование и материалы (включая палубу), фотоэлектрические поля (включая 35 кВ-электрические линии, поле)\nОборудование и установка оборудования, испытания и приемка оборудования, полная емкость станции и безопасность сети на 240 часов\nКонсультирование участников торгов по вопросам проверки качества, ...
#  '\n20230731_12345\nКитайский документ 67-9trans.txt\nХубэй собирает тендер на строительство гидроэнергетической станции\n(Контингент: CGN-202301310002)\nТерритория, в которой осуществляется тендерный проект: Хубэй, Хуанган, округ Чун\nУсловия торгов\nВ рамках проекта &lt; &lt; Хубэй &gt; &gt; велась работа по строительству гидроэнергетической станции (заявка на проект CGN-202301310002), которая была осуществлена по проекту\nУтверждено подразделением по утверждению, проект финансируется за счет собственных средств предприятия и уже реализован, а тендер - за счет компании &quot; Чайна нью-Энтерпрайз &quot; . Проект уже\nПри наличии условий для проведения торгов проводятся открытые торги.\nII. ОБЩИЙ ОБЗОР ПРОЕКТОВ, ОГРАНИЧЕННОСТИ И ПЛАНИРОВАНИЯ ПРОЕКТОВ\nРазмер проекта: &lt; &lt; Хубэй &gt; &gt; , &lt; &lt; Вай &gt; &gt; , &lt; &lt; Вэнвайн &gt; &gt; , &lt; &lt; Вай &gt; &gt; , &lt; &lt; Вэньгуань &gt; &gt; , &lt; &lt; Вэньчуань &gt; &gt; , провинция Хубэй, в коммуне Дуби, префектура, &lt; &lt; Вэньчуань &gt; &gt; и &lt; Дупи\nДлина составляет около 35 км, эта станция находится в 105 км от города Ухань и в 53 км от шоссе Хуанган, а также в центральной части Китая. электростанции\nНа станциях легко добраться, например, провинция S241 обеспечивает доступ к водосборному водохранилищу, а между верхним и нижним водохранилищами имеются сельские дороги.\nПервоначальная емкость станции составляет 298 МВт и 168 м воды. Электростанции строятся главным образом для систем электропередачи и новых водохранилищ. Вэй\nСтроительство водохранилища в Чжунцзяне, которое первоначально предусматривало нормальный уровень воды в 263 м, первоначальное общее регулирование емкости (по 6 ч) потребовало около 4,74 млн м3, а плотины использовали бетон.\nДеревянные дамбы. В водохранилище для использования существующего водохранилища по реке, который перехватывает водяные трещины с дождевой площадью 15,2 km2, общая емкость\n24 млн. м3.\nОсновными зданиями, построенными на узлах, являются водохранилища, водохранилища, системы водоснабжения, подземные сооружения и переключатели.\nСодержание и объем торгов:\nСодержание и сфера охвата данного тендера включают:\n1) строительство и эксплуатация электростанций и их вспомогательных сооружений;\n2) строительство электростанций 2, 3 и 4;\n3) строительство дренажных отверстий и плотин.\nВ рамках этого проекта были проведены конкурсы на проведение строительных работ по генеральному подряду, включая строительство, закупку, отладку, приемку и обслуживание в рамках проекта. Конкретный объем торгов\nБолее подробную информацию см. в тендерной технической документации.\nПланируемый период:\n347 календарных дней\n2.2 Дата начала работ 28 февраля 2023 года\n2.3 Дата завершения проекта 10 февраля 2024 года\nПримечание: Вышеуказанные даты являются датой начала и окончания первоначального плана, в зависимости от конкретного уведомления контролера, за исключением общих календарных дней каждого этапа.\nБез изменений.\nIII. Требования к кандидатам\n1. Основополагающая квалификация: участник процедур должен быть зарегистрирован на территории Китайской Народной Республики (за исключением Гонконга, Австралия) и иметь статус независимого юридического лица\n/ Компания, имеющая действительные лицензии юридического лица, выданные администрацией предприятия. Участники торгов должны иметь лицензию на безопасное производство и\nСрок действия.\nТребования к квалификации:\nДля участия в торгах требуется, чтобы участники торгов обладали такими качествами, как общий контракт на строительство гидроэлектроэнергии и выше. (если в соответствии с\nМинистерство по вопросам городского и сельского строительства в связи с выпуском циркуляра о программе реформы системы управления инженерно-строительными предприятиями в целях повышения квалификации или новых сертификатов для гидроэлектроэнергетики\nГенеральный контракт на строительство уровня А и выше).\n3.\nФинансовые требования:\nОтчет о финансовой ревизии за последние три года (2019-2021).\n4. Для аналогичн ...

# %%
# D = {
#     "I.": "Уведомление",
#     "II.": "Общий обзор проектов и ограничений",
#     "III.": "Требования к кандидатам",
#     "IV.": [
#         "ПРЕДСТАВЛЕНИЕ РЕКОМЕНДАЦИЙ ПО ПРОГРАММАМ",
#         "ПОЛУЧЕНИЕ ДОКУМЕНТОВ",
#         "ПРЕДСТАВЛЕНИЕ ДОКУМЕНТОВ",
#         "ПРЕДСТАВЛЕНИЕ ДОКУМЕНТОВ ПО ПРОГРАММАМ",
#     ],

#     # "Доступ к документам для посещения программ",
# }

SYMBOLS = ["II.", "III.", "IV.", "  ", "VI.", "VII", "VIII.", "IX"]

def parse_texts(texts: List[str]) -> Dict[int, Dict[str, str]]:
    res: Dict[int, Dict[str, str]] = {}
    for i, text in enumerate(texts):
        res[i] = parse_text(text)
    return res


def parse_text(text: str) -> Dict[str, str]:
    res: Dict[str, str] = {}
    rows = text.split("\n")
    cur = rows[0]
    tmp: List[str] = []
    for row in rows:
        if len(row) == 0:
            continue
        if row.split()[0] in SYMBOLS:
            res[cur] = "\n".join(tmp)
            tmp = []
            cur = row
        else:
            tmp.append(row)
    res[cur] = "\n".join(tmp)
    return res

# %%
def merge_text(tokens: List[Dict[str, Any]]):
    if len(tokens) == 0:
        return {}
    entities: Dict[str, List[str]] = {}
    start = tokens[0]["start"]
    end = tokens[0]["end"]
    entity = tokens[0]["entity"]
    for token in tokens[1:]:
        if end >= token["start"] - 1:
            end = token["end"]
        else:
            if entity in entities:
                entities[entity].append((start, end))
            else:
                entities[entity] = [(start, end)]
            start = token["start"]
            end = token["end"]
            entity = token["entity"]
    if entity in entities:
        entities[entity].append((start, end))
    else:
        entities[entity] = [(start, end)]
    return entities

# %%
def normalize_text(text: str) -> str:
    text = re.sub("\n", ". ", text)
    text = re.sub("\s+", " ", text)
    return text


def get_loc_org(data: List[Dict[str, str]], classifier: TokenClassificationPipeline) -> Tuple[List[str], List[str]]:
    res = []
    for id_doc, doc in tqdm(data.items()):
        glav_name, content = list(doc.items())[0]
        content = normalize_text(content)
        out = classifier(content)
        out = merge_text(out)
        d_tmp = {}
        for type_entity, entities in out.items():
            tmp = []
            for entity in entities:
                text_entity = content[entity[0]:entity[1]]
                tmp.append(text_entity)
            d_tmp[type_entity] = ",".join(set(tmp))
        res.append(d_tmp)
    loc = list(map(lambda x: x["I-LOC"] if "I-LOC" in x else "", res))
    org = list(map(lambda x: x["I-ORG"] if "I-ORG" in x else "", res))
    return loc, org

# %%
XLMRobertaTokenizerFast, XLMRobertaForTokenClassification
# Out:
# (transformers.models.xlm_roberta.tokenization_xlm_roberta_fast.XLMRobertaTokenizerFast,
#  transformers.models.xlm_roberta.modeling_xlm_roberta.XLMRobertaForTokenClassification)

# %%
tokenizer = XLMRobertaTokenizerFast.from_pretrained("xlm-roberta-large-finetuned-conll03-english")
model = XLMRobertaForTokenClassification.from_pretrained("xlm-roberta-large-finetuned-conll03-english")

device  = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
classifier = pipeline("ner", model=model, tokenizer=tokenizer, device=device)

data = parse_texts(df["text"].tolist())
# Out:
# Some weights of the model checkpoint at xlm-roberta-large-finetuned-conll03-english were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
loc, org = get_loc_org(data, classifier)

df["location"] = loc
df["organization"] = org
# Out:
#   0%|          | 0/1422 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
df[["location", "organization", "CGN"]].head(30)
# Out:
#                                                                         location  \
# 0                             Лоупе,Лоуп,Тэгу,район,Синьцзяне,Синьцзян-Уйгурский
# 1                                                              Хубэй,Хуанган,Чун
# 2                                                          Гуандун,Янцзы,Яньцзян
# 3                                                                        Шаньдун
# 4                                                                        Гуандун
# 5                                                                        Шаньдун
# 6                                                                        Шаньдун
# 7                                                                Гуандун,Цзянмен
# 8                                                              Шэньчжэнь,Гуандун
# 9                                                                  Гуандун,Янцзы
# 10                                                        Чжэцзян,Гуандун,Гуанси
# 11                                                                  Пекин,Тойота
# 12                                                           Шакуда,Сато,Гуандун
# 13  Гилонге,Гилон,Автономн,Чин,Чингх,Чинбэя,район Гуанси-Шань,Северный Чин,Генер
# 14                                                       Шэньчжэнь,Гуандун,Китае
# 15                                             Гуандун,Большого залива Шэньчжэнь
# 16                                                              Гуандун,Гуандуне
# 17                                                                     Шэньчжэнь
# 18                                                         Пекин,Гуанчжоу,Тойота
# 19                                                               Чжэцзян,Шаньдун
# 20                                                                       Шаньдун
# 21                                                                       Шаньдун
# 22                                                      Тир,Али,район,Тибете,Ali
# 23                                                             Шэньчжэнь,Гуандун
# 24                                                                     Шэньчжэнь
# 25                                                                       Гуандун
# 26                                                             Сиань,Чунси,Нанси
# 27                                                                       Шаньдун
# 28                                                                       Гуандун
# 29                                                Яблоке,Шаньдун,Ядерном острове
#
#                                   organization           CGN
# 0            China Solar Energy Successing Ltd  202307050014
# 1                   Хубэй,Чайна нью-Энтерпрайз  202301310002
# 2                                     Jiangian  202305150006
# 3                         источник,Чайна Хинси   20230307002
# 4                         Чайна инжиниринг лтд    2021223002
# 5                  SK,Чайна Инжиниринг лимитед  202304270004
# 6                                   Чайна Хинэ   20230609001
# 7                                  Тайшань АЭС   20221122001
# 8                   China Institute of Nuclear    2023024005
# 9                                     Jiangian   20230526004
# 10                       Чайна инжиниринг лтд.  202211110003
# 11                                              202307040015
# 12                       Чайна нью-йорка нью-д  202211230004
# 13                     ЕПК,EPC,Компания Чинбэй  202302210004
# 14                                              202304170003
# 15  Гуандун. Лимитед,Линтон энтерпрайз лимитед  202206270006
# 16                                  Чайна Хинэ   20221028003
# 17                            Золотой источник  202304240018
# 18                           Dun State Company   20230524002
# 19                    Чайна Инжиниринг лимитед  202307120001
# 20                    Чайна Инжиниринг лимитед   20230518002
# 21                       Чайна инжиниринг лтд.   20230620002
# 22                                         Али  202301180009
# 23                                 Чайна Хинан  202304030007
# 24                 Ling Atom,Lingong Line Line  202307120011
# 25    Чайна Хинонжиниринг лтд,Золотой источник   20230128002
# 26                                Энергопроект  202210190005
# 27                    Чайна Инжиниринг лимитед   20230116003
# 28                                              202304140006
# 29                    Чайна Инжиниринг лимитед  202303140012
